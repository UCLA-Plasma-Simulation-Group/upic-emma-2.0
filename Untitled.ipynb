# %%
# %matplotlib inline
import numpy as np
import sys

sys.path.append("/Users/uclapic/Documents/code-development/pyVisOS")

import osh5io
import osh5def
import osh5vis
import osh5utils
import matplotlib.pyplot as plt

# %%
c = osh5io.read_h5('/Users/uclapic/e2_cyl_m-1-re-000014.h5')
osh5vis.osplot(c)
# Out:
# (<matplotlib.image.AxesImage at 0x1334dce90>,
#  <matplotlib.colorbar.Colorbar at 0x13d020390>)
