# %%
import yt

# %%
import numpy as np
import matplotlib.pyplot as plt
from opmd_viewer import OpenPMDTimeSeries
# %matplotlib notebook
# or `%matplotlib inline` for non-interactive plots

# %%
ts = OpenPMDTimeSeries('EMF/')

# %%
ts.slider()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
f = yt.load('MS/E3/*.h5')

# %%
for handles in f:
    print handles
# Out:
# yt : [ERROR    ] 2018-05-10 10:53:57,355 Couldn't figure out output type for MS/E3/E300000000.h5
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-10-8d39f893e22a> in <module>()
# ----> 1 for handles in f:
#       2     print handles
#
# /Users/uclapic/anaconda/lib/python2.7/site-packages/yt/data_objects/time_series.pyc in __iter__(self)
#     179         for o in self._pre_outputs:
#     180             if isinstance(o, string_types):
# --> 181                 ds = self._load(o, **self.kwargs)
#     182                 self._setup_function(ds)
#     183                 yield ds
#
# /Users/uclapic/anaconda/lib/python2.7/site-packages/yt/data_objects/time_series.pyc in _load(self, output_fn, **kwargs)
#     396         elif self._mixed_dataset_types:
#     397             return load(output_fn, **kwargs)
# --> 398         ds = load(output_fn, **kwargs)
# ...

# %%
f[1].derived_field_list
# Out:
# yt : [ERROR    ] 2018-05-10 11:10:40,539 Couldn't figure out output type for MS/E3/E300000003.h5
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-16-be9b4734d291> in <module>()
# ----> 1 f[1].derived_field_list
#
# /Users/uclapic/anaconda/lib/python2.7/site-packages/yt/data_objects/time_series.pyc in __getitem__(self, key)
#     193         o = self._pre_outputs[key]
#     194         if isinstance(o, string_types):
# --> 195             o = self._load(o, **self.kwargs)
#     196             self._setup_function(o)
#     197         return o
#
# /Users/uclapic/anaconda/lib/python2.7/site-packages/yt/data_objects/time_series.pyc in _load(self, output_fn, **kwargs)
#     396         elif self._mixed_dataset_types:
#     397             return load(output_fn, **kwargs)
# --> 398         ds = load(output_fn, **kwargs)
# ...
